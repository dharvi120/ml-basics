# %% [markdown]
# <a href="https://colab.research.google.com/github/dharvi120/ml-basics/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# preprocessing + EDA+ feature selection
#extract input nd output columns
#scale the value
#train test split
# train the model
#evaluate the model and model selection
# deploy model

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df= df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
x=df.iloc[:,0:2] # independent variable
y=df.iloc[:,-1]  #  dependent variable

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 32   7.0  139.0
# 21   7.1  151.0
# 50   3.5  233.0
# 89   4.9  151.0
# 62   6.0  102.0
# ..   ...    ...
# 33   6.0  149.0
# 23   4.7   87.0
# 73   4.9   61.0
# 7    5.0   63.0
# 63   6.3  128.0
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 10    1
# 1     0
# 11    1
# 59    0
# 67    0
# 46    0
# 93    1
# 99    1
# 4     0
# 72    1
# Name: placement, dtype: int64

# %%
#scaling

from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.86282776,  0.34486768],
#        [ 0.94825625,  0.63860356],
#        [-2.12716943,  2.64579873],
#        [-0.93117055,  0.63860356],
#        [ 0.00854285, -0.56081795],
#        [-0.76031357,  0.07560979],
#        [ 0.4356853 , -2.15188729],
#        [-1.70002697, -0.60977393],
#        [ 0.69197078, -0.85455382],
#        [-0.67488508,  0.88338346],
#        [-0.93117055,  1.7401131 ],
#        [ 0.4356853 ,  0.85890547],
#        [-1.4437415 ,  1.83802506],
#        [-0.84574206, -0.83007583],
#        [ 0.35025681,  0.39382366],
#        [-0.5040281 ,  0.34486768],
#        [ 0.77739927, -0.70768589],
#        [ 0.4356853 , -0.85455382],
#        [-0.67488508, -0.36499403],
#        [ 0.4356853 ,  0.12456577],
#        [ 1.71711267, -1.12381171],
#        [-0.58945659, -0.09573614],
#        [ 0.00854285, -1.44202558],
#        [-0.24774262,  0.44277964],
#        [-0.93117055,  0.73651552],
#        [ 1.28997022, -1.56441553],
#        [ 0.77739927,  0.34486768],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.00854285, -1.95606337],
#        [-0.07688564, -0.46290599],
#        [ 0.77739927,  0.32038969],
#        [-1.01659904, -0.31603805],
#        [-0.84574206, -0.16917011],
#        [-0.58945659, -0.26708207],
#        [ 0.69197078, -0.31603805],
#        [ 0.17939983, -0.29156006],
#        [-0.16231413,  0.41830165],
#        [ 1.11911323, -0.21812609]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
# model train

# %%
clf= LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 10    1
# 1     0
# 11    1
# 59    0
# 67    0
# 46    0
# 93    1
# 99    1
# 4     0
# 72    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# Plotting decision regions
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('placement.pkl','wb'))

# %%
#heroku for hosting
